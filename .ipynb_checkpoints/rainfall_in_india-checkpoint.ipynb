# %%
# import dependencies
import pandas as pd

# %%
# read in csv for rainfall data
rainfall_df = pd.read_csv("rainfall in india 1901-2015-FILTERED.csv")
rainfall_df
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4106                LAKSHADWEEP  2010  18.8    0.0   1.2   35.6   79.0  318.9
# 4107                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4108                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4109                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4110                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
#
# ...

# %%
# filter data for only 2015
rainfall_2015_df = rainfall_df[rainfall_df['YEAR'] == 2015]
rainfall_2015_df.head()
# Out:
#            SUBDIVISION  YEAR    JAN   FEB   MAR    APR    MAY    JUN    JUL  \
# 109  ANDAMAN & NICOBAR  2015  126.8   7.6   3.1  138.2  331.9  346.4  328.9
# 206     ANDHRA PRADESH  2015    2.0   0.6   5.5   32.3   34.1  283.8  116.0
# 321  ARUNACHAL PRADESH  2015   30.8  47.5  97.5  287.1  238.9  637.9  329.3
# 436              ASSAM  2015   13.4  15.5  37.5  250.9  332.5  558.5  300.1
# 551              BIHAR  2015   12.8   1.8  27.2   38.7   39.5  122.1  231.5
#
#        AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# 109  480.0  523.3  252.1  236.3  129.9  2904.6    134.4    473.2   1678.6
# 206  192.0  201.8   59.7   81.2    2.0  1010.9      2.5     71.9    793.6
# 321  595.5  374.2   65.2   33.8   29.8  2767.5     78.3    623.5   1936.9
# 436  590.9  279.9   62.6   14.0   15.2  2470.9     28.9    620.9   1729.3
# 551  287.0  101.7   10.4    0.0    0.0   872.7     14.6    105.5    742.3
#
#      Oct-Dec
# 109    618.4
# 206    142.8
# 321    128.8
# ...

# %%
# dropped all but the 'SUBDIVISION' and 'ANNUAL' columns
annual_rainfall_2015_df = rainfall_2015_df[['SUBDIVISION', 'ANNUAL']]
annual_rainfall_2015_df
# Out:
#              SUBDIVISION  ANNUAL
# 109    ANDAMAN & NICOBAR  2904.6
# 206       ANDHRA PRADESH  1010.9
# 321    ARUNACHAL PRADESH  2767.5
# 436                ASSAM  2470.9
# 551                BIHAR   872.7
# 666           CHANDIGARH   435.3
# 781         CHHATTISGARH  1117.6
# 896                  GOA  2082.0
# 1011             GUJARAT   622.9
# 1126    HIMACHAL PRADESH  1210.5
# 1241     JAMMU & KASHMIR  1572.8
# 1356           JHARKHAND  1081.8
# 1471           KARNATAKA  3106.0
# 1700              KERALA  2600.6
# 1815         LAKSHADWEEP  1642.9
# 1930         MAHARASHTRA   644.5
# 2045      MADHYA PRADESH   939.2
# 2160          MATATHWADA   532.2
# 2275            NAGALAND  1922.4
# 2390              ORISSA  1210.1
# 2505              PUNJAB   510.8
# 2620           RAJASTHAN   650.7
# 2735          RAYALSEEMA  1047.1
# 2850  SAURASHTRA & KUTCH   441.7
# 2965              SIKKIM  2518.6
# 3080          TAMIL NADU  1204.6
# 3309           TELANGANA   857.3
# ...

# %%
# read cuisine csv
indian_food_df = pd.read_csv("Indian_Food_Cuisine.csv")
indian_food_df['state'] = indian_food_df['state'].str.upper()
indian_food_df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  WEST BENGAL
# 1  vegetarian         80         30          sweet  dessert    RAJASTHAN
# 2  vegetarian         15         60          sweet  dessert       PUNJAB
# 3  vegetarian         15         30          sweet  dessert    RAJASTHAN
# 4  vegetarian         15         40          sweet  dessert  WEST BENGAL
#
#   region  avg_rating  orders_num  num_rating
# 0   East         4.0          20          10
# ...

# %%
# read in state codes
state_codes_df = pd.read_excel("State codes.xlsx")
state_codes_df.head()
# Out:
#                     STATE TWO-LETTER CODE
# 0  (FORMERLY UTTARANCHAL)             NaN
# 1       ANDAMAN & NICOBAR              AN
# 2          ANDHRA PRADESH              AP
# 3       ARUNACHAL PRADESH              AR
# 4                   ASSAM              AS

# %%
# merge the indian_food_df and state_codes_df dataframes on state
indian_food_codes_df = indian_food_df.merge(state_codes_df, left_on="state", right_on="STATE", how='inner')
indian_food_codes_df
# Out:
#             name                                        ingredients  \
# 0     Balu shahi                    Maida flour, yogurt, oil, sugar
# 1    Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 2         Imarti                          Sugar syrup, lentil flour
# 3       Kalakand                        Milk, cottage cheese, sugar
# 4      Cham cham  Flour, cream, sugar, saffron, lemon juice, coc...
# ..           ...                                                ...
# 213       Laapsi   Cinnamon, jaggery, clarified butter, dry roasted
# 214    Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 215     Vindaloo  Chicken, coconut oil, wine vinegar, ginger, gr...
# 216      Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 217       Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 0        vegetarian         45         25          sweet      dessert
# ...

# %%
# drop the duplicate column "STATE" after merge
indian_food_codes_df = indian_food_codes_df.drop("STATE", axis = 1)
indian_food_codes_df
# Out:
#             name                                        ingredients  \
# 0     Balu shahi                    Maida flour, yogurt, oil, sugar
# 1    Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 2         Imarti                          Sugar syrup, lentil flour
# 3       Kalakand                        Milk, cottage cheese, sugar
# 4      Cham cham  Flour, cream, sugar, saffron, lemon juice, coc...
# ..           ...                                                ...
# 213       Laapsi   Cinnamon, jaggery, clarified butter, dry roasted
# 214    Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 215     Vindaloo  Chicken, coconut oil, wine vinegar, ginger, gr...
# 216      Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 217       Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 0        vegetarian         45         25          sweet      dessert
# ...

# %%
# rename "TWO-LETTER CODE" column to "State Code"
indian_food_codes_df = indian_food_codes_df.rename(columns={"TWO-LETTER CODE":"State Code"})
indian_food_codes_df
# Out:
#             name                                        ingredients  \
# 0     Balu shahi                    Maida flour, yogurt, oil, sugar
# 1    Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 2         Imarti                          Sugar syrup, lentil flour
# 3       Kalakand                        Milk, cottage cheese, sugar
# 4      Cham cham  Flour, cream, sugar, saffron, lemon juice, coc...
# ..           ...                                                ...
# 213       Laapsi   Cinnamon, jaggery, clarified butter, dry roasted
# 214    Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 215     Vindaloo  Chicken, coconut oil, wine vinegar, ginger, gr...
# 216      Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 217       Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 0        vegetarian         45         25          sweet      dessert
# ...

# %%
# merge annual_rainfall_2015_codes_df and state_codes_df on "SUBDIVISION" and "STATE", respectively
annual_rainfall_2015_codes_df = annual_rainfall_2015_df.merge(state_codes_df, left_on="SUBDIVISION", right_on="STATE", how='inner')
annual_rainfall_2015_codes_df
# Out:
#           SUBDIVISION  ANNUAL              STATE TWO-LETTER CODE
# 0   ANDAMAN & NICOBAR  2904.6  ANDAMAN & NICOBAR              AN
# 1      ANDHRA PRADESH  1010.9     ANDHRA PRADESH              AP
# 2   ARUNACHAL PRADESH  2767.5  ARUNACHAL PRADESH              AR
# 3               ASSAM  2470.9              ASSAM              AS
# 4               BIHAR   872.7              BIHAR              BR
# 5          CHANDIGARH   435.3         CHANDIGARH              CH
# 6        CHHATTISGARH  1117.6       CHHATTISGARH              CG
# 7                 GOA  2082.0                GOA              GA
# 8             GUJARAT   622.9            GUJARAT              GJ
# 9    HIMACHAL PRADESH  1210.5   HIMACHAL PRADESH              HP
# 10    JAMMU & KASHMIR  1572.8    JAMMU & KASHMIR              JK
# 11          JHARKHAND  1081.8          JHARKHAND              JS
# 12          KARNATAKA  3106.0          KARNATAKA              KA
# ...

# %%
# drop the duplicate state name "SUBDIVISION" column
annual_rainfall_2015_codes_df = annual_rainfall_2015_codes_df.drop("SUBDIVISION", axis = 1)
annual_rainfall_2015_codes_df
# Out:
#     ANNUAL              STATE TWO-LETTER CODE
# 0   2904.6  ANDAMAN & NICOBAR              AN
# 1   1010.9     ANDHRA PRADESH              AP
# 2   2767.5  ARUNACHAL PRADESH              AR
# 3   2470.9              ASSAM              AS
# 4    872.7              BIHAR              BR
# 5    435.3         CHANDIGARH              CH
# 6   1117.6       CHHATTISGARH              CG
# 7   2082.0                GOA              GA
# 8    622.9            GUJARAT              GJ
# 9   1210.5   HIMACHAL PRADESH              HP
# 10  1572.8    JAMMU & KASHMIR              JK
# 11  1081.8          JHARKHAND              JS
# 12  3106.0          KARNATAKA              KA
# 13  2600.6             KERALA              KL
# 14  1642.9        LAKSHADWEEP              LD
# 15   644.5        MAHARASHTRA              MH
# 16   939.2     MADHYA PRADESH              MP
# 17  1922.4           NAGALAND              NL
# 18  1210.1             ORISSA              OR
# ...

# %%
# indian_food_rainfall_codes_df = indian_food_codes_df and annual_rainfall_2015_codes_df on "State Code" and "TWO-LETTER CODE", respectively
indian_food_rainfall_codes_df = indian_food_codes_df.merge(annual_rainfall_2015_codes_df, left_on="State Code", right_on="TWO-LETTER CODE", how = "left")
indian_food_rainfall_codes_df
# Out:
#             name                                        ingredients  \
# 0     Balu shahi                    Maida flour, yogurt, oil, sugar
# 1    Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 2         Imarti                          Sugar syrup, lentil flour
# 3       Kalakand                        Milk, cottage cheese, sugar
# 4      Cham cham  Flour, cream, sugar, saffron, lemon juice, coc...
# ..           ...                                                ...
# 213       Laapsi   Cinnamon, jaggery, clarified butter, dry roasted
# 214    Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 215     Vindaloo  Chicken, coconut oil, wine vinegar, ginger, gr...
# 216      Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 217       Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 0        vegetarian         45         25          sweet      dessert
# ...

# %%
# drop the "STATE" and "TWO-LETTER CODE" columns
indian_food_rainfall_codes_df = indian_food_rainfall_codes_df.drop(["STATE", "TWO-LETTER CODE"], axis =1)
indian_food_rainfall_codes_df
# Out:
#             name                                        ingredients  \
# 0     Balu shahi                    Maida flour, yogurt, oil, sugar
# 1    Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 2         Imarti                          Sugar syrup, lentil flour
# 3       Kalakand                        Milk, cottage cheese, sugar
# 4      Cham cham  Flour, cream, sugar, saffron, lemon juice, coc...
# ..           ...                                                ...
# 213       Laapsi   Cinnamon, jaggery, clarified butter, dry roasted
# 214    Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 215     Vindaloo  Chicken, coconut oil, wine vinegar, ginger, gr...
# 216      Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 217       Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 0        vegetarian         45         25          sweet      dessert
# ...

# %%
# rename 'ANNUAL' to 'Annual Rainfall (mm)'
indian_food_rainfall_codes_df = indian_food_rainfall_codes_df.rename(columns={'ANNUAL': 'Annual Rainfall (mm)'})
indian_food_rainfall_codes_df
# Out:
#             name                                        ingredients  \
# 0     Balu shahi                    Maida flour, yogurt, oil, sugar
# 1    Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 2         Imarti                          Sugar syrup, lentil flour
# 3       Kalakand                        Milk, cottage cheese, sugar
# 4      Cham cham  Flour, cream, sugar, saffron, lemon juice, coc...
# ..           ...                                                ...
# 213       Laapsi   Cinnamon, jaggery, clarified butter, dry roasted
# 214    Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 215     Vindaloo  Chicken, coconut oil, wine vinegar, ginger, gr...
# 216      Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 217       Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 0        vegetarian         45         25          sweet      dessert
# ...
